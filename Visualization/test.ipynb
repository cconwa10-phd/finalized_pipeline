# %%
from plotnine.data import economics
import plotnine as p9
import pandas as pd

# %%
(
        p9.ggplot(data = economics, mapping=p9.aes(x='date', y='pop'))
    + p9.geom_line()
)
# Out:
# <ggplot: (8766812413125)>
